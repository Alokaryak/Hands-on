# %%
print("First Code In Python using Jupyter Notebook")
# Out:
# First Code In Python using Jupyter Notebook

# %%
print("I am a runner")
# Out:
# I am a runner

# %%
name = "Alok"
age = 27
height = 5.5
is_student = False
print("Name is::",name)
print("Age is::",age)
print("Height is::",height)
print("Is she a student::",is_student)
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Name is:: Alok
# Age is:: 27
# Height is:: 5.5
# Is she a student:: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = input()
print(name)
